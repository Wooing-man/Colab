# %% [markdown]
# ## Dacon 코드 필사!
# **해당 내용들은 데이콘 리더보드를 보며 공부한 내용임 --> [본 페이지](https://dacon.io/competitions/official/236036/codeshare/7480?page=1&dtype=recent)**
# ### 주제: 기계 고장 진단 AI 경진대회
#
# > - 꿀레도르(리더보드 1위) : Fast Fourier transform & Autoencoder
#
#
# ### 요약
# - 회전체의 특성을 표현하기 위해 FFT 사용
# - 1초씩 나누어 FFT를 수행 후 전체를 평균하여 시간의 흐름에 따른 주파수 특성 변화를 반영
# - FFT 과정에서 Hannning window를 사용하여 Data leakage 방지
#
# - Autoencoder를 사용해 정상데이터를 학습하고, 손실함수는 MAE 사용
# - 정상/이상을 판별하기 위한 score로 MAE를 사용하였으며, 정상데이터에서 가장 큰 score T를 임계치로 설정
# - 설정한 임계치 t를 기준으로 t를 넘지 않는 경우 정상으로 판정하고, 넘는 경우 이상으로 판정

# %% [markdown]
# ----

# %% [markdown]
# #### Modeule Import

# %%
import random
import pandas as pd
import numpy as np
import os
import time
import librosa
import librosa.display
import IPython.display as ipd
from tqdm.auto import tqdm
from collections import Counter

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torchsummary import summary
from torch import optim

import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn-white')
# Out:
# <ipython-input-1-86530c04957a>:21: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-white')
